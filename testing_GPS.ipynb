# %%
import k_fail_GPS
import BB_wrapper
import k_fail_prediction

import torch
# Out:
# /Users/karim/projects/k-sPSS/.venv/lib/python3.11/site-packages/pycutest/__init__.py:26: RuntimeWarning: the PYCUTEST_CACHE environment variable is not set; current folder will be used for caching.
#   warnings.warn("the PYCUTEST_CACHE environment variable is not set; current folder will be used for caching.", RuntimeWarning)

# %% [markdown]
# # Wrapper

# %%
cutest_wrapper = BB_wrapper.BB_cutest_collection(write_to_file="cutest_problem_selection.txt", max_dim=100, cap_n_problems=1)
# Out:
# loading problems...
# 0/276
# loaded 1 problems

# %%
# evaluating n problem functions
for i in range(1):
    p = cutest_wrapper.problems[i]
    f = cutest_wrapper.problem_functions[i]
    print(f"{p.name} | n: {p.n}: {f(torch.from_numpy(p.x0))}")
# Out:
# SISSER | n: 2: 3.02030030003

# %%
problem_idx = 0
k = 0
k_fail_wrapper = BB_wrapper.BB_k_fail_wrapper(cutest_wrapper.problem_functions[problem_idx], k*torch.ones((1024, 2), dtype=torch.int16))

# %% [markdown]
# # GPS

# %%
alg = k_fail_GPS.GPS_k_fail(torch.from_numpy(cutest_wrapper.problems[problem_idx].x0), k_fail_wrapper, delta=1, tao=0.5, prediction_software=k_fail_prediction.constant_prediction_software(k), log_file_path="alg_logs/GPS/testing.txt")

# %%
alg.log_current(message=f"k={k}")
for i in range(100):
    alg.step_default(random_rotate=True)


# SPIN2LS delta=1000 tao=0.95
# 1411 with rotation
# 1447 without so idk

# CHWIRUT2LS delta=1, tao=0.95
# 1648 with
# 1846 without

# %%
cutest_wrapper.problem_functions[problem_idx](torch.zeros(n_dim))
# Out:
# inf

# %%
print(cutest_wrapper.problems[problem_idx].bl)
print(cutest_wrapper.problems[problem_idx].bu)
# Out:
# [-1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20
#  -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20
#  -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20
#  -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20
#  -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20
#  -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20
#  -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20
#  -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20
#  -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20
#  -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20
#  -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20 -1.e+20
#  -1.e+20 -1.e+20 -1.e+20]
# [1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20
#  1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20
#  1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20
#  1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20
#  1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20
#  1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20
#  1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20
#  1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20
#  1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20
#  1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20 1.e+20
#  1.e+20 1.e+20]

# %%
import pycutest
import numpy as np

p = pycutest.import_problem("SPIN2LS")
p.obj(np.zeros(n_dim)) # WHA???? NAN???
# Out:
# nan
