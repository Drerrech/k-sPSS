# %%
import k_fail_GPS
import k_fail_MBTR
import BB_wrapper
import k_fail_prediction

import torch
# Out:
# /Users/karim/projects/k-sPSS/.venv/lib/python3.11/site-packages/pycutest/__init__.py:26: RuntimeWarning: the PYCUTEST_CACHE environment variable is not set; current folder will be used for caching.
#   warnings.warn("the PYCUTEST_CACHE environment variable is not set; current folder will be used for caching.", RuntimeWarning)

# %% [markdown]
# # Test Set

# %%
cap_n_problems = 24

cutest_wrapper = BB_wrapper.BB_cutest_collection(write_to_file="hyperparam_tuning/cutest_problem_selection_hyperparam_tuning.txt", max_dim=100, cap_n_problems=cap_n_problems,
                problem_names=[
    "SISSER",
    # "CHWIRUT2LS",
    "DENSCHNB", "GBRAINLS",
    # "MGH10LS",
    "QING",
    # "BOX3",
    "DENSCHNC",
    # "LANCZOS3LS",
    # "GAUSS1LS",
    "MGH09LS",
    # "LANCZOS1LS",
    # "BA-L1LS",
    # "GAUSS3LS",
    "DENSCHNA",
    # "NELSONLS",
    "LUKSAN21LS", "VANDANMSLS",
    "SENSORS",
    # "DENSCHND",
    # "DANWOODLS",
    "CUBE", "MUONSINELS",
    # "DENSCHNE",
    "DMN15333LS", "DIAMON3DLS",
    # "EXPFIT",
    "HELIX", "LSC2LS", "KOWOSB",
    "S308", "DANIWOODLS", "DENSCHNF", "LRIJCNN1", "YFITU",
    # "GAUSS2LS",
    # "CHWIRUT1LS",
    "COOLHANSLS", "HAHN1LS",
    # "HIMMELBB",
                ])
# problem idx: 6 gets <= -1e20
# problem idx: 8 gets <= -1e20
# problem idx: 11 gets <= -1e20
# problem idx: 20 gets <= -1e20

# BOX3
# LANCZOS3LS
# LANCZOS1LS
# DANWOODLS
# CHWIRUT2LS
# MGH10LS
# GAUSS1LS
# BA-L1LS
# GAUSS3LS
# NELSONLS
# DENSCHND
# DENSCHNE
# EXPFIT a
# GAUSS2LS
# CHWIRUT1LS
# HIMMELBB
# Out:
# loading problems...
# 0/24
# 20/24
# loaded 24 problems

# %%
# evaluating n problem functions
for i in range(cap_n_problems):
    p = cutest_wrapper.problems[i]
    f = cutest_wrapper.problem_functions[i]
    print(f"idx: {i} | {p.name} | n: {p.n}: {f(torch.from_numpy(p.x0))}")
# Out:
# idx: 0 | SISSER | n: 2: 3.02030030003
# idx: 1 | DENSCHNB | n: 2: 6.0
# idx: 2 | GBRAINLS | n: 2: 41.0311021275977
# idx: 3 | QING | n: 100: 328350.0
# idx: 4 | DENSCHNC | n: 2: 889.3031475218829
# idx: 5 | MGH09LS | n: 4: 897.5453780404945
# idx: 6 | DENSCHNA | n: 2: 7.952492442012559
# idx: 7 | LUKSAN21LS | n: 100: 99.98750720029557
# idx: 8 | VANDANMSLS | n: 22: 15.000017496625823
# idx: 9 | SENSORS | n: 100: -56.48140005456502
# idx: 10 | CUBE | n: 2: 749.0383999999999
# idx: 11 | MUONSINELS | n: 1: 61302.97680759
# idx: 12 | DMN15333LS | n: 99: 484133.4482526387
# idx: 13 | DIAMON3DLS | n: 99: 4028942.9527573423
# idx: 14 | HELIX | n: 3: 2499.999798289702
# idx: 15 | LSC2LS | n: 3: 235144.35341171772
# idx: 16 | KOWOSB | n: 4: 0.005313615358191823
# idx: 17 | S308 | n: 2: 87.68604814559544
# idx: 18 | DANIWOODLS | n: 2: 149.71921907712198
# idx: 19 | DENSCHNF | n: 2: 416.0
# idx: 20 | LRIJCNN1 | n: 22: 1.528013678381445
# idx: 21 | YFITU | n: 3: 2340.4195868458514
# idx: 22 | COOLHANSLS | n: 9: 902930.45122
# idx: 23 | HAHN1LS | n: 7: 3097556.5274337744

# %%
from collections import Counter 
import matplotlib.pyplot as plt

def count_problems_by_n(filepath: str) -> None:
    counter = Counter()
 
    with open(filepath) as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            parts = line.split('|')
            if len(parts) < 4:
                continue
            try:
                n = int(parts[3].strip())
                counter[n] += 1
            except ValueError:
                continue  # skip header or malformed lines
 
    print(f"{'n':>6} {'num_problems':>12}")
    print("-" * 20)
    for n in sorted(counter):
        print(f"{n:>6} {counter[n]:>12}")
 
    ns = sorted(counter)
    counts = [counter[n] for n in ns]
 
    fig, ax = plt.subplots(figsize=(10, 5))
    ax.bar([str(n) for n in ns], counts, color="steelblue", edgecolor="white")
    ax.set_xlabel("n")
    ax.set_ylabel("number of problems")
    ax.set_title("number of problems by n")
    plt.xticks(rotation=45, ha="right")
    plt.tight_layout()
    plt.show()

count_problems_by_n("hyperparam_tuning/cutest_problem_selection_hyperparam_tuning.txt")
# Out:
#      n num_problems
# --------------------
#      1            1
#      2            9
#      3            3
#      4            2
#      7            1
#      9            1
#     22            2
#     99            2
#    100            3

# %% [markdown]
# # Algorithm Wrappers

# %%
import time
import os

TIME_LIMIT_S = 600.0

def read_last_fx(filename):
    last_fx = None
    with open(filename, "r") as f:
        for line in f:
            line = line.strip()
            # Skip header and empty lines
            if not line or line.startswith("k"):
                continue
            parts = [p.strip() for p in line.split("|")]
            if len(parts) >= 3:
                try:
                    last_fx = float(parts[2])
                except ValueError:
                    pass
    return last_fx

# %%
def gps_expl_path_batch_constrained(problem_idx, num_cpus, k, delta, tao, n_batch_calls_limit):
    log_file_path = f"alg_logs/GPS/profile_testing_{problem_idx}_{delta:.2f}_{tao:.2f}_{n_batch_calls_limit}_expl_gps.txt"
    if os.path.exists(log_file_path):
        return log_file_path
    
    GPS_expl_k_fail_wrapper = BB_wrapper.BB_k_fail_wrapper(cutest_wrapper.problem_functions[problem_idx], k*torch.ones((1024, 2), dtype=torch.int16), num_cpus)
    alg = k_fail_GPS.GPS_k_fail(torch.from_numpy(cutest_wrapper.problems[problem_idx].x0), GPS_expl_k_fail_wrapper, delta, tao, prediction_software=k_fail_prediction.constant_prediction_software(k), log_file_path=log_file_path) # exploitation and utilisation are true by default

    alg.log_current(message=f"k={k}")
    
    start_time = time.time()

    while alg.n_batch_calls < n_batch_calls_limit:
        if time.time() - start_time >= TIME_LIMIT_S:
            # print("TIME LIMIT")
            with open("alg_logs/GPS/timeout_list.txt", "a") as f:
                f.write(f"TIME LIMIT REACHED ON: {problem_idx} | {cutest_wrapper.problems[problem_idx]} | x_k = {alg.x} | f(x) = {alg.cur_f_val}\n")
            break
        alg.step_default(random_rotate=True)
    
    # return best function value so far
    return log_file_path

# %%
def mbtr_expl_path_batch_constrained(problem_idx, num_cpus, k, delta, mu, eta, gamma, eps_stop, opportunistic_cpu_exploitation_manual_point_limit, preferred_model_order, n_batch_calls_limit): # eps stop also should be searched for because it is responsible for not wasting function calls, the algorithm knows when a solution is good
    log_file_path = f"alg_logs/MBTR/profile_testing_{problem_idx}_{delta:.2f}_{mu:.2f}_{eta:.2f}_{gamma:.2f}_{eps_stop:.2f}_{preferred_model_order}_{opportunistic_cpu_exploitation_manual_point_limit}_{n_batch_calls_limit}_expl_mbtr.txt"
    if os.path.exists(log_file_path):
        return log_file_path

    MBTR_expl_k_fail_wrapper = BB_wrapper.BB_k_fail_wrapper(cutest_wrapper.problem_functions[problem_idx], k*torch.ones((1024, 2), dtype=torch.int16), num_cpus)

    alg = k_fail_MBTR.MBTR_k_fail(torch.from_numpy(cutest_wrapper.problems[problem_idx].x0), MBTR_expl_k_fail_wrapper, delta, mu, eta, gamma, eps_stop, prediction_software=k_fail_prediction.constant_prediction_software(k), log_file_path=log_file_path,
                                  preferred_model_order=preferred_model_order, # cpu exploitation is on by default
                                  opportunistic_cpu_exploitation_manual_point_limit=opportunistic_cpu_exploitation_manual_point_limit)
    
    alg.log_current()

    start_time = time.time()

    while alg.n_batch_calls < n_batch_calls_limit:
        if time.time() - start_time >= TIME_LIMIT_S:
            # print("TIME LIMIT")
            with open("alg_logs/MBTR/timeout_list.txt", "a") as f:
                f.write(f"TIME LIMIT REACHED ON: {problem_idx} | {cutest_wrapper.problems[problem_idx]} | x_k = {alg.x} | f(x) = {alg.cur_f_val}\n")
            break
        alg.step_default()
    
    # return best function value so far
    return log_file_path

# %% [markdown]
# # GPS and MBTR hyperparameters and cluster settings

# %%
# cluster
# number of cpus will be determined for each problem manually
num_cpus_dim_brackets = [
    [4, 4], # n < 4 -> 4 cpus
    [8, 8],
    [16, 16],
    [32, 32],
    [64, 64],
    [128, 128],
]
k_ratios = [ # portion of cpus failing, will be rounded up
    0.0,
    0.05,
    0.1,
    0.2,
]


# GPS
gps_delta = 1.0
gps_tau = 0.3

# MBTR ORDER 1
mbtr_1_delta = 1.0
mbtr_1_mu = 1.5 # 1.0
mbtr_1_eta = 0.1
mbtr_1_gamma = 0.5
mbtr_1_eps_stop = 0.0

# MBTR ORDER 2
mbtr_2_delta = 1.0
mbtr_2_mu = 1.5 # 1.0
mbtr_2_eta = 0.1
mbtr_2_gamma = 0.25
mbtr_2_eps_stop = 0.0

# MBTR function limit
mbtr_model_function_lim = lambda n: 4*n

# %% [markdown]
# # Run the algorithms

# %%
from IPython.display import clear_output
from tqdm.notebook import tqdm
import math

N_BATCH_LIMIT = 160

log_paths = [
    [],
    [],
    [],
]

# %%
# GPS

pbar = tqdm(total=cap_n_problems * len(k_ratios))

for problem_idx in range(cap_n_problems):
    for k_ratio_idx in range(len(k_ratios)):
        problem_n = cutest_wrapper.problems[problem_idx].n

        num_cpus = num_cpus_dim_brackets[0][1]
        for dim, cpus in num_cpus_dim_brackets:
            num_cpus = cpus
            if dim > problem_n:
                break
        
        k = math.ceil(num_cpus * k_ratios[k_ratio_idx])

        log_paths[0].append(gps_expl_path_batch_constrained(problem_idx, num_cpus, k, gps_delta, gps_tau, N_BATCH_LIMIT))

        clear_output(wait=True)
        pbar.update(1)

pbar.close()
# Out:
#   0%|          | 0/96 [00:00<?, ?it/s]

# %%
# MBTR ORDER 1

pbar = tqdm(total=cap_n_problems * len(k_ratios))

for problem_idx in range(cap_n_problems):
    for k_ratio_idx in range(len(k_ratios)):
        problem_n = cutest_wrapper.problems[problem_idx].n

        num_cpus = num_cpus_dim_brackets[0][1]
        for dim, cpus in num_cpus_dim_brackets:
            num_cpus = cpus
            if dim > problem_n:
                break
        
        k = math.ceil(num_cpus * k_ratios[k_ratio_idx])

        log_paths[1].append(mbtr_expl_path_batch_constrained(problem_idx, num_cpus, k, mbtr_1_delta, mbtr_1_mu, mbtr_1_eta, mbtr_1_gamma, mbtr_1_eps_stop, mbtr_model_function_lim(problem_n), 1, N_BATCH_LIMIT))

        clear_output(wait=True)
        pbar.update(1)

pbar.close()
# Out:
#   0%|          | 0/96 [00:00<?, ?it/s]

# %%
# MBTR ORDER 2

pbar = tqdm(total=cap_n_problems * len(k_ratios))

for problem_idx in range(cap_n_problems):
    for k_ratio_idx in range(len(k_ratios)):
        problem_n = cutest_wrapper.problems[problem_idx].n

        num_cpus = num_cpus_dim_brackets[0][1]
        for dim, cpus in num_cpus_dim_brackets:
            num_cpus = cpus
            if dim > problem_n:
                break
        
        k = math.ceil(num_cpus * k_ratios[k_ratio_idx])

        log_paths[2].append(mbtr_expl_path_batch_constrained(problem_idx, num_cpus, k, mbtr_2_delta, mbtr_2_mu, mbtr_2_eta, mbtr_2_gamma, mbtr_2_eps_stop, mbtr_model_function_lim(problem_n), 2, N_BATCH_LIMIT))

        clear_output(wait=True)
        pbar.update(1)

pbar.close()
# Out:
#   0%|          | 0/96 [00:00<?, ?it/s]

# %% [markdown]
# # Plot the results

# %%
import profiles

alg_names = ["GPS", "MBTR-1", "MBTR-2"]
NUM_ALGS = len(alg_names)

# %%
tau = 0.1
alpha_vals = torch.linspace(1, 16, 32)

profile_vals = profiles.performance_profile(NUM_ALGS, cap_n_problems, log_paths, tau, alpha_vals=alpha_vals)
profiles.plot_performance_profile(profile_vals, tau, alg_names, alpha_vals=alpha_vals)

# %%
tau = 0.1
k_vals = torch.linspace(1, 64, 32)

problem_dims = torch.zeros(cap_n_problems)
for i in range(cap_n_problems):
    problem_dims[i] = cutest_wrapper.problems[i].n

profile_vals = profiles.data_profile(NUM_ALGS, cap_n_problems, log_paths, tau, problem_dims, k_vals)
profiles.plot_data_profile(profile_vals, tau, alg_names, k_vals)

# %%
print(f"GPS              | MBTR-1           | MBTR-2")
for i in range(len(log_paths[0])):
    print(f"{read_last_fx(log_paths[0][i]):16.2f} | {read_last_fx(log_paths[1][i]):16.2f} | {read_last_fx(log_paths[2][i]):16.2f} # {[log_paths[_][i] for _ in range(NUM_ALGS)]}")
# Out:
# GPS              | MBTR-1           | MBTR-2
#             0.00 |             0.00 |             0.00 # ['alg_logs/GPS/profile_testing_0_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_0_1.00_1.00_0.10_0.50_0.00_1_8_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_0_1.00_1.00_0.10_0.40_0.00_2_8_1024_expl_mbtr.txt']
#             0.00 |             0.00 |             0.00 # ['alg_logs/GPS/profile_testing_0_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_0_1.00_1.00_0.10_0.50_0.00_1_8_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_0_1.00_1.00_0.10_0.40_0.00_2_8_1024_expl_mbtr.txt']
#             0.00 |             0.00 |             0.00 # ['alg_logs/GPS/profile_testing_0_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_0_1.00_1.00_0.10_0.50_0.00_1_8_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_0_1.00_1.00_0.10_0.40_0.00_2_8_1024_expl_mbtr.txt']
#             0.00 |             0.00 |             0.00 # ['alg_logs/GPS/profile_testing_0_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_0_1.00_1.00_0.10_0.50_0.00_1_8_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_0_1.00_1.00_0.10_0.40_0.00_2_8_1024_expl_mbtr.txt']
#             0.00 |             0.00 |             0.00 # ['alg_logs/GPS/profile_testing_1_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_1_1.00_1.00_0.10_0.50_0.00_1_8_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_1_1.00_1.00_0.10_0.40_0.00_2_8_1024_expl_mbtr.txt']
#             0.00 |             0.00 |             0.00 # ['alg_logs/GPS/profile_testing_1_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_1_1.00_1.00_0.10_0.50_0.00_1_8_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_1_1.00_1.00_0.10_0.40_0.00_2_8_1024_expl_mbtr.txt']
#             0.00 |             0.00 |             0.00 # ['alg_logs/GPS/profile_testing_1_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_1_1.00_1.00_0.10_0.50_0.00_1_8_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_1_1.00_1.00_0.10_0.40_0.00_2_8_1024_expl_mbtr.txt']
#             0.00 |             0.00 |             0.00 # ['alg_logs/GPS/profile_testing_1_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_1_1.00_1.00_0.10_0.50_0.00_1_8_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_1_1.00_1.00_0.10_0.40_0.00_2_8_1024_expl_mbtr.txt']
#            28.52 |            32.99 |            33.07 # ['alg_logs/GPS/profile_testing_2_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_2_1.00_1.00_0.10_0.50_0.00_1_8_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_2_1.00_1.00_0.10_0.40_0.00_2_8_1024_expl_mbtr.txt']
#            28.52 |            32.99 |            33.07 # ['alg_logs/GPS/profile_testing_2_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_2_1.00_1.00_0.10_0.50_0.00_1_8_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_2_1.00_1.00_0.10_0.40_0.00_2_8_1024_expl_mbtr.txt']
#            28.52 |            32.99 |            33.07 # ['alg_logs/GPS/profile_testing_2_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_2_1.00_1.00_0.10_0.50_0.00_1_8_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_2_1.00_1.00_0.10_0.40_0.00_2_8_1024_expl_mbtr.txt']
#            28.52 |            32.99 |            33.07 # ['alg_logs/GPS/profile_testing_2_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_2_1.00_1.00_0.10_0.50_0.00_1_8_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_2_1.00_1.00_0.10_0.40_0.00_2_8_1024_expl_mbtr.txt']
#            23.08 |         29893.49 |          9120.42 # ['alg_logs/GPS/profile_testing_3_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_3_1.00_1.00_0.10_0.50_0.00_1_400_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_3_1.00_1.00_0.10_0.40_0.00_2_400_1024_expl_mbtr.txt']
#            23.08 |         29893.49 |          9120.42 # ['alg_logs/GPS/profile_testing_3_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_3_1.00_1.00_0.10_0.50_0.00_1_400_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_3_1.00_1.00_0.10_0.40_0.00_2_400_1024_expl_mbtr.txt']
#            23.08 |         29893.49 |          9120.42 # ['alg_logs/GPS/profile_testing_3_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_3_1.00_1.00_0.10_0.50_0.00_1_400_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_3_1.00_1.00_0.10_0.40_0.00_2_400_1024_expl_mbtr.txt']
#            23.08 |         29893.49 |          9120.42 # ['alg_logs/GPS/profile_testing_3_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_3_1.00_1.00_0.10_0.50_0.00_1_400_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_3_1.00_1.00_0.10_0.40_0.00_2_400_1024_expl_mbtr.txt']
#             0.00 |             0.00 |             0.00 # ['alg_logs/GPS/profile_testing_4_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_4_1.00_1.00_0.10_0.50_0.00_1_8_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_4_1.00_1.00_0.10_0.40_0.00_2_8_1024_expl_mbtr.txt']
#             0.00 |             0.00 |             0.00 # ['alg_logs/GPS/profile_testing_4_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_4_1.00_1.00_0.10_0.50_0.00_1_8_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_4_1.00_1.00_0.10_0.40_0.00_2_8_1024_expl_mbtr.txt']
#             0.00 |             0.00 |             0.00 # ['alg_logs/GPS/profile_testing_4_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_4_1.00_1.00_0.10_0.50_0.00_1_8_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_4_1.00_1.00_0.10_0.40_0.00_2_8_1024_expl_mbtr.txt']
#             0.00 |             0.00 |             0.00 # ['alg_logs/GPS/profile_testing_4_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_4_1.00_1.00_0.10_0.50_0.00_1_8_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_4_1.00_1.00_0.10_0.40_0.00_2_8_1024_expl_mbtr.txt']
#             0.01 |             0.02 |             0.01 # ['alg_logs/GPS/profile_testing_5_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_5_1.00_1.00_0.10_0.50_0.00_1_16_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_5_1.00_1.00_0.10_0.40_0.00_2_16_1024_expl_mbtr.txt']
#             0.01 |             0.02 |             0.01 # ['alg_logs/GPS/profile_testing_5_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_5_1.00_1.00_0.10_0.50_0.00_1_16_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_5_1.00_1.00_0.10_0.40_0.00_2_16_1024_expl_mbtr.txt']
#             0.01 |             0.02 |             0.01 # ['alg_logs/GPS/profile_testing_5_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_5_1.00_1.00_0.10_0.50_0.00_1_16_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_5_1.00_1.00_0.10_0.40_0.00_2_16_1024_expl_mbtr.txt']
#             0.01 |             0.02 |             0.01 # ['alg_logs/GPS/profile_testing_5_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_5_1.00_1.00_0.10_0.50_0.00_1_16_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_5_1.00_1.00_0.10_0.40_0.00_2_16_1024_expl_mbtr.txt']
#             0.00 |             0.00 |             0.00 # ['alg_logs/GPS/profile_testing_6_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_6_1.00_1.00_0.10_0.50_0.00_1_8_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_6_1.00_1.00_0.10_0.40_0.00_2_8_1024_expl_mbtr.txt']
#             0.00 |             0.00 |             0.00 # ['alg_logs/GPS/profile_testing_6_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_6_1.00_1.00_0.10_0.50_0.00_1_8_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_6_1.00_1.00_0.10_0.40_0.00_2_8_1024_expl_mbtr.txt']
#             0.00 |             0.00 |             0.00 # ['alg_logs/GPS/profile_testing_6_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_6_1.00_1.00_0.10_0.50_0.00_1_8_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_6_1.00_1.00_0.10_0.40_0.00_2_8_1024_expl_mbtr.txt']
#             0.00 |             0.00 |             0.00 # ['alg_logs/GPS/profile_testing_6_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_6_1.00_1.00_0.10_0.50_0.00_1_8_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_6_1.00_1.00_0.10_0.40_0.00_2_8_1024_expl_mbtr.txt']
#            91.80 |            99.54 |            99.24 # ['alg_logs/GPS/profile_testing_7_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_7_1.00_1.00_0.10_0.50_0.00_1_400_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_7_1.00_1.00_0.10_0.40_0.00_2_400_1024_expl_mbtr.txt']
#            91.80 |            99.54 |            99.24 # ['alg_logs/GPS/profile_testing_7_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_7_1.00_1.00_0.10_0.50_0.00_1_400_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_7_1.00_1.00_0.10_0.40_0.00_2_400_1024_expl_mbtr.txt']
#            91.80 |            99.54 |            99.24 # ['alg_logs/GPS/profile_testing_7_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_7_1.00_1.00_0.10_0.50_0.00_1_400_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_7_1.00_1.00_0.10_0.40_0.00_2_400_1024_expl_mbtr.txt']
#            91.80 |            99.54 |            99.24 # ['alg_logs/GPS/profile_testing_7_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_7_1.00_1.00_0.10_0.50_0.00_1_400_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_7_1.00_1.00_0.10_0.40_0.00_2_400_1024_expl_mbtr.txt']
#            11.56 |            12.14 |            12.14 # ['alg_logs/GPS/profile_testing_8_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_8_1.00_1.00_0.10_0.50_0.00_1_88_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_8_1.00_1.00_0.10_0.40_0.00_2_88_1024_expl_mbtr.txt']
#            11.56 |            12.14 |            12.14 # ['alg_logs/GPS/profile_testing_8_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_8_1.00_1.00_0.10_0.50_0.00_1_88_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_8_1.00_1.00_0.10_0.40_0.00_2_88_1024_expl_mbtr.txt']
#            11.56 |            12.14 |            12.14 # ['alg_logs/GPS/profile_testing_8_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_8_1.00_1.00_0.10_0.50_0.00_1_88_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_8_1.00_1.00_0.10_0.40_0.00_2_88_1024_expl_mbtr.txt']
#            11.56 |            12.14 |            12.14 # ['alg_logs/GPS/profile_testing_8_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_8_1.00_1.00_0.10_0.50_0.00_1_88_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_8_1.00_1.00_0.10_0.40_0.00_2_88_1024_expl_mbtr.txt']
#         -2109.28 |         -1968.70 |         -2079.43 # ['alg_logs/GPS/profile_testing_9_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_9_1.00_1.00_0.10_0.50_0.00_1_400_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_9_1.00_1.00_0.10_0.40_0.00_2_400_1024_expl_mbtr.txt']
#         -2109.28 |         -1968.70 |         -2079.43 # ['alg_logs/GPS/profile_testing_9_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_9_1.00_1.00_0.10_0.50_0.00_1_400_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_9_1.00_1.00_0.10_0.40_0.00_2_400_1024_expl_mbtr.txt']
#         -2109.28 |         -1968.70 |         -2079.43 # ['alg_logs/GPS/profile_testing_9_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_9_1.00_1.00_0.10_0.50_0.00_1_400_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_9_1.00_1.00_0.10_0.40_0.00_2_400_1024_expl_mbtr.txt']
#         -2109.28 |         -1968.70 |         -2079.43 # ['alg_logs/GPS/profile_testing_9_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_9_1.00_1.00_0.10_0.50_0.00_1_400_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_9_1.00_1.00_0.10_0.40_0.00_2_400_1024_expl_mbtr.txt']
#             0.00 |             0.05 |             0.05 # ['alg_logs/GPS/profile_testing_10_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_10_1.00_1.00_0.10_0.50_0.00_1_8_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_10_1.00_1.00_0.10_0.40_0.00_2_8_1024_expl_mbtr.txt']
#             0.00 |             0.05 |             0.05 # ['alg_logs/GPS/profile_testing_10_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_10_1.00_1.00_0.10_0.50_0.00_1_8_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_10_1.00_1.00_0.10_0.40_0.00_2_8_1024_expl_mbtr.txt']
#             0.00 |             0.05 |             0.05 # ['alg_logs/GPS/profile_testing_10_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_10_1.00_1.00_0.10_0.50_0.00_1_8_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_10_1.00_1.00_0.10_0.40_0.00_2_8_1024_expl_mbtr.txt']
#             0.00 |             0.05 |             0.05 # ['alg_logs/GPS/profile_testing_10_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_10_1.00_1.00_0.10_0.50_0.00_1_8_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_10_1.00_1.00_0.10_0.40_0.00_2_8_1024_expl_mbtr.txt']
#             0.00 |             0.00 |             0.00 # ['alg_logs/GPS/profile_testing_11_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_11_1.00_1.00_0.10_0.50_0.00_1_4_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_11_1.00_1.00_0.10_0.40_0.00_2_4_1024_expl_mbtr.txt']
#             0.00 |             0.00 |             0.00 # ['alg_logs/GPS/profile_testing_11_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_11_1.00_1.00_0.10_0.50_0.00_1_4_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_11_1.00_1.00_0.10_0.40_0.00_2_4_1024_expl_mbtr.txt']
#             0.00 |             0.00 |             0.00 # ['alg_logs/GPS/profile_testing_11_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_11_1.00_1.00_0.10_0.50_0.00_1_4_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_11_1.00_1.00_0.10_0.40_0.00_2_4_1024_expl_mbtr.txt']
#             0.00 |             0.00 |             0.00 # ['alg_logs/GPS/profile_testing_11_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_11_1.00_1.00_0.10_0.50_0.00_1_4_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_11_1.00_1.00_0.10_0.40_0.00_2_4_1024_expl_mbtr.txt']
#          1055.42 |          5109.18 |          1124.14 # ['alg_logs/GPS/profile_testing_12_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_12_1.00_1.00_0.10_0.50_0.00_1_396_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_12_1.00_1.00_0.10_0.40_0.00_2_396_1024_expl_mbtr.txt']
#          1055.42 |          5109.18 |          1124.14 # ['alg_logs/GPS/profile_testing_12_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_12_1.00_1.00_0.10_0.50_0.00_1_396_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_12_1.00_1.00_0.10_0.40_0.00_2_396_1024_expl_mbtr.txt']
#          1055.42 |          5109.18 |          1124.14 # ['alg_logs/GPS/profile_testing_12_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_12_1.00_1.00_0.10_0.50_0.00_1_396_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_12_1.00_1.00_0.10_0.40_0.00_2_396_1024_expl_mbtr.txt']
#          1055.42 |          5109.18 |          1124.14 # ['alg_logs/GPS/profile_testing_12_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_12_1.00_1.00_0.10_0.50_0.00_1_396_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_12_1.00_1.00_0.10_0.40_0.00_2_396_1024_expl_mbtr.txt']
#          5952.96 |         21655.12 |          7926.89 # ['alg_logs/GPS/profile_testing_13_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_13_1.00_1.00_0.10_0.50_0.00_1_396_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_13_1.00_1.00_0.10_0.40_0.00_2_396_1024_expl_mbtr.txt']
#          5952.96 |         21655.12 |          7926.89 # ['alg_logs/GPS/profile_testing_13_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_13_1.00_1.00_0.10_0.50_0.00_1_396_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_13_1.00_1.00_0.10_0.40_0.00_2_396_1024_expl_mbtr.txt']
#          5952.96 |         21655.12 |          7926.89 # ['alg_logs/GPS/profile_testing_13_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_13_1.00_1.00_0.10_0.50_0.00_1_396_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_13_1.00_1.00_0.10_0.40_0.00_2_396_1024_expl_mbtr.txt']
#          5952.96 |         21655.12 |          7926.89 # ['alg_logs/GPS/profile_testing_13_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_13_1.00_1.00_0.10_0.50_0.00_1_396_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_13_1.00_1.00_0.10_0.40_0.00_2_396_1024_expl_mbtr.txt']
#             0.00 |             0.27 |             0.99 # ['alg_logs/GPS/profile_testing_14_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_14_1.00_1.00_0.10_0.50_0.00_1_12_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_14_1.00_1.00_0.10_0.40_0.00_2_12_1024_expl_mbtr.txt']
#             0.00 |             0.27 |             0.99 # ['alg_logs/GPS/profile_testing_14_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_14_1.00_1.00_0.10_0.50_0.00_1_12_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_14_1.00_1.00_0.10_0.40_0.00_2_12_1024_expl_mbtr.txt']
#             0.00 |             0.27 |             0.99 # ['alg_logs/GPS/profile_testing_14_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_14_1.00_1.00_0.10_0.50_0.00_1_12_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_14_1.00_1.00_0.10_0.40_0.00_2_12_1024_expl_mbtr.txt']
#             0.00 |             0.27 |             0.99 # ['alg_logs/GPS/profile_testing_14_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_14_1.00_1.00_0.10_0.50_0.00_1_12_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_14_1.00_1.00_0.10_0.40_0.00_2_12_1024_expl_mbtr.txt']
#            16.80 |            79.70 |            18.50 # ['alg_logs/GPS/profile_testing_15_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_15_1.00_1.00_0.10_0.50_0.00_1_12_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_15_1.00_1.00_0.10_0.40_0.00_2_12_1024_expl_mbtr.txt']
#            16.80 |            79.70 |            18.50 # ['alg_logs/GPS/profile_testing_15_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_15_1.00_1.00_0.10_0.50_0.00_1_12_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_15_1.00_1.00_0.10_0.40_0.00_2_12_1024_expl_mbtr.txt']
#            16.80 |            79.70 |            18.50 # ['alg_logs/GPS/profile_testing_15_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_15_1.00_1.00_0.10_0.50_0.00_1_12_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_15_1.00_1.00_0.10_0.40_0.00_2_12_1024_expl_mbtr.txt']
#            16.80 |            79.70 |            18.50 # ['alg_logs/GPS/profile_testing_15_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_15_1.00_1.00_0.10_0.50_0.00_1_12_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_15_1.00_1.00_0.10_0.40_0.00_2_12_1024_expl_mbtr.txt']
#             0.00 |             0.00 |             0.00 # ['alg_logs/GPS/profile_testing_16_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_16_1.00_1.00_0.10_0.50_0.00_1_16_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_16_1.00_1.00_0.10_0.40_0.00_2_16_1024_expl_mbtr.txt']
#             0.00 |             0.00 |             0.00 # ['alg_logs/GPS/profile_testing_16_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_16_1.00_1.00_0.10_0.50_0.00_1_16_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_16_1.00_1.00_0.10_0.40_0.00_2_16_1024_expl_mbtr.txt']
#             0.00 |             0.00 |             0.00 # ['alg_logs/GPS/profile_testing_16_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_16_1.00_1.00_0.10_0.50_0.00_1_16_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_16_1.00_1.00_0.10_0.40_0.00_2_16_1024_expl_mbtr.txt']
#             0.00 |             0.00 |             0.00 # ['alg_logs/GPS/profile_testing_16_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_16_1.00_1.00_0.10_0.50_0.00_1_16_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_16_1.00_1.00_0.10_0.40_0.00_2_16_1024_expl_mbtr.txt']
#             0.77 |             0.77 |             0.77 # ['alg_logs/GPS/profile_testing_17_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_17_1.00_1.00_0.10_0.50_0.00_1_8_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_17_1.00_1.00_0.10_0.40_0.00_2_8_1024_expl_mbtr.txt']
#             0.77 |             0.77 |             0.77 # ['alg_logs/GPS/profile_testing_17_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_17_1.00_1.00_0.10_0.50_0.00_1_8_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_17_1.00_1.00_0.10_0.40_0.00_2_8_1024_expl_mbtr.txt']
#             0.77 |             0.77 |             0.77 # ['alg_logs/GPS/profile_testing_17_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_17_1.00_1.00_0.10_0.50_0.00_1_8_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_17_1.00_1.00_0.10_0.40_0.00_2_8_1024_expl_mbtr.txt']
#             0.77 |             0.77 |             0.77 # ['alg_logs/GPS/profile_testing_17_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_17_1.00_1.00_0.10_0.50_0.00_1_8_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_17_1.00_1.00_0.10_0.40_0.00_2_8_1024_expl_mbtr.txt']
#             0.00 |             0.07 |             0.09 # ['alg_logs/GPS/profile_testing_18_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_18_1.00_1.00_0.10_0.50_0.00_1_8_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_18_1.00_1.00_0.10_0.40_0.00_2_8_1024_expl_mbtr.txt']
#             0.00 |             0.07 |             0.09 # ['alg_logs/GPS/profile_testing_18_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_18_1.00_1.00_0.10_0.50_0.00_1_8_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_18_1.00_1.00_0.10_0.40_0.00_2_8_1024_expl_mbtr.txt']
#             0.00 |             0.07 |             0.09 # ['alg_logs/GPS/profile_testing_18_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_18_1.00_1.00_0.10_0.50_0.00_1_8_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_18_1.00_1.00_0.10_0.40_0.00_2_8_1024_expl_mbtr.txt']
#             0.00 |             0.07 |             0.09 # ['alg_logs/GPS/profile_testing_18_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_18_1.00_1.00_0.10_0.50_0.00_1_8_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_18_1.00_1.00_0.10_0.40_0.00_2_8_1024_expl_mbtr.txt']
#             0.00 |             0.00 |             0.00 # ['alg_logs/GPS/profile_testing_19_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_19_1.00_1.00_0.10_0.50_0.00_1_8_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_19_1.00_1.00_0.10_0.40_0.00_2_8_1024_expl_mbtr.txt']
#             0.00 |             0.00 |             0.00 # ['alg_logs/GPS/profile_testing_19_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_19_1.00_1.00_0.10_0.50_0.00_1_8_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_19_1.00_1.00_0.10_0.40_0.00_2_8_1024_expl_mbtr.txt']
#             0.00 |             0.00 |             0.00 # ['alg_logs/GPS/profile_testing_19_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_19_1.00_1.00_0.10_0.50_0.00_1_8_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_19_1.00_1.00_0.10_0.40_0.00_2_8_1024_expl_mbtr.txt']
#             0.00 |             0.00 |             0.00 # ['alg_logs/GPS/profile_testing_19_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_19_1.00_1.00_0.10_0.50_0.00_1_8_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_19_1.00_1.00_0.10_0.40_0.00_2_8_1024_expl_mbtr.txt']
#             0.27 |             0.37 |             0.37 # ['alg_logs/GPS/profile_testing_20_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_20_1.00_1.00_0.10_0.50_0.00_1_88_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_20_1.00_1.00_0.10_0.40_0.00_2_88_1024_expl_mbtr.txt']
#             0.27 |             0.37 |             0.37 # ['alg_logs/GPS/profile_testing_20_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_20_1.00_1.00_0.10_0.50_0.00_1_88_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_20_1.00_1.00_0.10_0.40_0.00_2_88_1024_expl_mbtr.txt']
#             0.27 |             0.37 |             0.37 # ['alg_logs/GPS/profile_testing_20_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_20_1.00_1.00_0.10_0.50_0.00_1_88_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_20_1.00_1.00_0.10_0.40_0.00_2_88_1024_expl_mbtr.txt']
#             0.27 |             0.37 |             0.37 # ['alg_logs/GPS/profile_testing_20_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_20_1.00_1.00_0.10_0.50_0.00_1_88_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_20_1.00_1.00_0.10_0.40_0.00_2_88_1024_expl_mbtr.txt']
#           184.31 |           216.07 |           216.63 # ['alg_logs/GPS/profile_testing_21_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_21_1.00_1.00_0.10_0.50_0.00_1_12_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_21_1.00_1.00_0.10_0.40_0.00_2_12_1024_expl_mbtr.txt']
#           184.31 |           216.07 |           216.63 # ['alg_logs/GPS/profile_testing_21_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_21_1.00_1.00_0.10_0.50_0.00_1_12_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_21_1.00_1.00_0.10_0.40_0.00_2_12_1024_expl_mbtr.txt']
#           184.31 |           216.07 |           216.63 # ['alg_logs/GPS/profile_testing_21_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_21_1.00_1.00_0.10_0.50_0.00_1_12_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_21_1.00_1.00_0.10_0.40_0.00_2_12_1024_expl_mbtr.txt']
#           184.31 |           216.07 |           216.63 # ['alg_logs/GPS/profile_testing_21_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_21_1.00_1.00_0.10_0.50_0.00_1_12_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_21_1.00_1.00_0.10_0.40_0.00_2_12_1024_expl_mbtr.txt']
#             0.04 |             3.42 |             0.87 # ['alg_logs/GPS/profile_testing_22_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_22_1.00_1.00_0.10_0.50_0.00_1_36_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_22_1.00_1.00_0.10_0.40_0.00_2_36_1024_expl_mbtr.txt']
#             0.04 |             3.42 |             0.87 # ['alg_logs/GPS/profile_testing_22_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_22_1.00_1.00_0.10_0.50_0.00_1_36_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_22_1.00_1.00_0.10_0.40_0.00_2_36_1024_expl_mbtr.txt']
#             0.04 |             3.42 |             0.87 # ['alg_logs/GPS/profile_testing_22_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_22_1.00_1.00_0.10_0.50_0.00_1_36_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_22_1.00_1.00_0.10_0.40_0.00_2_36_1024_expl_mbtr.txt']
#             0.04 |             3.42 |             0.87 # ['alg_logs/GPS/profile_testing_22_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_22_1.00_1.00_0.10_0.50_0.00_1_36_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_22_1.00_1.00_0.10_0.40_0.00_2_36_1024_expl_mbtr.txt']
#          4333.65 |          4782.11 |          7769.42 # ['alg_logs/GPS/profile_testing_23_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_23_1.00_1.00_0.10_0.50_0.00_1_28_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_23_1.00_1.00_0.10_0.40_0.00_2_28_1024_expl_mbtr.txt']
#          4333.65 |          4782.11 |          7769.42 # ['alg_logs/GPS/profile_testing_23_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_23_1.00_1.00_0.10_0.50_0.00_1_28_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_23_1.00_1.00_0.10_0.40_0.00_2_28_1024_expl_mbtr.txt']
#          4333.65 |          4782.11 |          7769.42 # ['alg_logs/GPS/profile_testing_23_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_23_1.00_1.00_0.10_0.50_0.00_1_28_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_23_1.00_1.00_0.10_0.40_0.00_2_28_1024_expl_mbtr.txt']
#          4333.65 |          4782.11 |          7769.42 # ['alg_logs/GPS/profile_testing_23_1.00_0.30_1024_expl_gps.txt', 'alg_logs/MBTR/profile_testing_23_1.00_1.00_0.10_0.50_0.00_1_28_1024_expl_mbtr.txt', 'alg_logs/MBTR/profile_testing_23_1.00_1.00_0.10_0.40_0.00_2_28_1024_expl_mbtr.txt']

# %%
import ast
import numpy as np
import matplotlib.pyplot as plt

def plot_x_deltas(log_path):
    xs = []
    with open(log_path, "r") as f:
        skipped_first = False
        for line in f:
            if not skipped_first or not line.strip():
                skipped_first = True
                continue
            elems = line.split("|")
            x = ast.literal_eval(elems[1].strip())
            xs.append(np.array(x))

    deltas = [np.linalg.norm(xs[i+1] - xs[i]) for i in range(len(xs) - 1)]

    plt.figure(figsize=(10, 4))
    plt.plot(deltas, drawstyle="steps-post", linewidth=1.5)
    plt.xlabel("k")
    plt.ylabel("||x_{k+1} - x_k||")
    plt.title("Distance between consecutive iterates")
    plt.grid(True, linestyle="--", alpha=0.5)
    plt.tight_layout()
    plt.show()

# %%
plot_x_deltas("alg_logs/MBTR/profile_testing_7_1.00_1.00_0.10_0.50_0.00_1_400_1024_expl_mbtr.txt")

# %%
plot_x_deltas("alg_logs/MBTR/profile_testing_7_1.00_1.00_0.10_0.40_0.00_2_400_1024_expl_mbtr.txt")

# %%
plot_x_deltas("alg_logs/GPS/profile_testing_7_1.00_0.30_1024_expl_gps.txt")
